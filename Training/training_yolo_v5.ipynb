# %%
# !pip install ultralytics
# !pip install roboflow

# %% [markdown]
# # Get Datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QWnrcDH9z1LGiIn7xLyX")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(17)
dataset = version.download("yolov5")

# %%
dataset.location

# %%
import shutil

shutil.move('football-players-detection-17/test',
            'football-players-detection-17/football-players-detection-17/test'
)
shutil.move('football-players-detection-17/train',
            'football-players-detection-17/football-players-detection-17/train'
)
shutil.move('football-players-detection-17/valid',
            'football-players-detection-17/football-players-detection-17/valid'
)

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model=yolov5x.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
